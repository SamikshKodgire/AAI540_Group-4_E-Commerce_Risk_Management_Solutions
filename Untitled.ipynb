# %%
import pandas as pd

df = pd.read_csv(
    "s3://high-risk-ecommerce-mlops-group4-aai540/processed-data/final_ml_dataset.csv"
)

df.head()
# Out:
#    payment_value  payment_installments   price  freight_value  item_count  \
# 0          38.71                   1.0   29.99           8.72         1.0
# 1         141.46                   1.0  118.70          22.76         1.0
# 2         179.12                   3.0  159.90          19.22         1.0
# 3          72.20                   1.0   45.00          27.20         1.0
# 4          28.62                   1.0   19.90           8.72         1.0
#
#    delivery_delay_days  review_score product_category_name_english  high_risk
# 0                 -8.0           4.0                    housewares          0
# 1                 -6.0           4.0                     perfumery          0
# 2                -18.0           5.0                          auto          0
# 3                -13.0           5.0                      pet_shop          0
# 4                -10.0           5.0                    stationery          0
